# %% [markdown]
# # SURAKSHA: 01. Exploratory Data Analysis
# ### Spatial Unified Risk Assessment & Knowledge-based Settlement Housing Allocation
# This notebook explores vulnerable habitations, historical disaster frequencies, and candidate resettlement sites across the pilot corridor.

# %%
import pandas as pd
import numpy as np
import json

# Load pilot habitations
with open('../data/sample/pilot_region/habitations.json') as f:
    hab_data = json.load(f)
df_habs = pd.DataFrame(hab_data)
print(f"Loaded {len(df_habs)} habitations for analysis:")
df_habs[['id', 'name', 'region', 'hazard', 'pop']]

# %%
# Factor distribution statistics
factors_df = pd.DataFrame([h['f'] for h in hab_data])
factors_df['name'] = df_habs['name']
factors_df.describe()
