# %% [markdown]
# # SURAKSHA: 02. Multi-Hazard Susceptibility Model
# Trains and evaluates a Random Forest classifier to demarcate critical hazard zones.

# %%
from backend.ml.hazard_model.train import train_hazard_model
from backend.ml.hazard_model.predict import predict_hazard_susceptibility

# Train or load model
model = train_hazard_model()
print("Model classes:", model.classes_)

# %%
# Test sample prediction
sample = {
    "slope_deg": 42.0,
    "rainfall_mm": 310.0,
    "elevation_m": 1200.0,
    "distance_to_fault_km": 2.5,
    "soil_permeability": 0.35
}
result = predict_hazard_susceptibility(sample)
print("Hazard Prediction:", result)
